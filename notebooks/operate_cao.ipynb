# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2

metrics_df = pd.read_csv("../statics/metrics_20_0.csv")

# %% [markdown]
# ### Prepare CAOs
# Means to link them, and integrate 10% test data

# %%
from agent.components.commons import ServiceType
from agent.components.CAO import CAO

producer: CAO = CAO(ServiceType.CV)
worker: CAO = CAO(ServiceType.QR)
consumer: CAO = CAO(ServiceType.PC)

consumer.add_upstream_CAO(worker)
worker.add_upstream_CAO(producer)

producer.integrate_observations(metrics_df, data_density=0.1)
worker.integrate_observations(metrics_df, data_density=0.1)
consumer.integrate_observations(metrics_df, data_density=0.1)
# Out:
# INFO:GP_Model:Fitting GP for elastic-workbench-cv-analyzer - Target: max_tp
# /home/boris/development/composable-autonomous-offerings/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__sigma_0 is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# INFO:multiscale:train_gp_models took 20 ms to execute
# Iteration 0: Elite found in bin (np.int64(2), np.int64(3), np.int64(0)) with fitness 0.0657
# Iteration 100: Elite found in bin (np.int64(8), np.int64(5), np.int64(2)) with fitness 0.1227
# Iteration 300: Elite found in bin (np.int64(7), np.int64(8), np.int64(1)) with fitness 0.1909
# Iteration 400: Elite found in bin (np.int64(1), np.int64(0), np.int64(0)) with fitness 0.0694
# Iteration 500: Elite found in bin (np.int64(1), np.int64(5), np.int64(1)) with fitness 0.0074
# Iteration 600: Elite found in bin (np.int64(6), np.int64(5), np.int64(2)) with fitness 0.0720
# INFO:GP_Model:Fitting GP for elastic-workbench-qr-detector - Target: max_tp
# Iteration 700: Elite found in bin (np.int64(4), np.int64(3), np.int64(2)) with fitness 0.0764
# /home/boris/development/composable-autonomous-offerings/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__sigma_0 is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# INFO:multiscale:train_gp_models took 109 ms to execute
# Iteration 0: Elite found in bin (np.int64(8), np.int64(4)) with fitness 0.2645
# Iteration 300: Elite found in bin (np.int64(0), np.int64(1)) with fitness 0.4166
# Iteration 400: Elite found in bin (np.int64(4), np.int64(2)) with fitness 0.7253
# INFO:GP_Model:Fitting GP for elastic-workbench-pc-visualizer - Target: max_tp
# /home/boris/development/composable-autonomous-offerings/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__sigma_0 is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/boris/development/composable-autonomous-offerings/.venv/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__k1__constant_value is close to the specified lower bound 0.001. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# INFO:multiscale:train_gp_models took 33 ms to execute
# Iteration 0: Elite found in bin (np.int64(7), np.int64(8)) with fitness 0.8008
# Iteration 100: Elite found in bin (np.int64(8), np.int64(2)) with fitness 0.8457
# Iteration 500: Elite found in bin (np.int64(4), np.int64(8)) with fitness 0.5377

# %% [markdown]
# ### Get PFO of leaf node

# %%
from agent.components.commons import ServiceVar

consumer.get_CAO_fitness()

print(producer.config[ServiceVar.COST])
print(worker.config[ServiceVar.COST])
print(consumer.config[ServiceVar.COST])

print(producer.config[ServiceVar.PERFORMANCE])
print(worker.config[ServiceVar.PERFORMANCE])
print(consumer.config[ServiceVar.PERFORMANCE])

print(producer.config[ServiceVar.QUALITY])
print(worker.config[ServiceVar.QUALITY])
print(consumer.config[ServiceVar.QUALITY])
# Out:
# Cumulative cost: 1.1607216877049753
# Min performance: 0.1802612656824237
# Min quality: 0.09449023149351791
# 0.6597629283051158
# 0.10880576050712021
# 0.3921529988927392
# 0.24574684020136636
# 0.1802612656824237
# 0.40128988123996145
# 0.09449023149351791
# 0.7109329738104561
# 0.20655711986729935
